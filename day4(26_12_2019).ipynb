# %%
x=10 
y=20.45
z=4+5j 
a=True 
s="string1" 
s1='string2'
print(type(x),type(y),type(z),type(a),type(s),type(s1))
# Out:
# <class 'int'> <class 'float'> <class 'complex'> <class 'bool'> <class 'str'> <class 'str'>

# %%
print(s)
print(s[5])
print(s[6])
print(s[-1])
print(s[2:6])
print(s[::2])
print(s[::-1])
# Out:
# string1
# g
# 1
# 1
# ring
# srn1
# 1gnirts

# %%
a=input("enter a")
b=input("enter b")
a,b=b,a #swap
print(a,b)
# Out:
# enter a2
# enter b6
# 6 2

# %%
#palindrome 
str1=input("enter a string")
print(str1==str1[::1])
# Out:
# enter a stringmadam
# True

# %%
#built-in functions
x=10
y=str(10) #converts number to string
print(len(s)) #length of characters in the string
print(min(s)) #the char that has the least ascii value
print(max(s))
print(y)
# Out:
# 7
# 1
# t
# 10

# %%
ord('1')
# Out:
# 49

# %%
chr(65)
# Out:
# 'A'

# %% [markdown]
# #string built-in methods
# 1.isalpha()
# 2.isdigit()
# 3.isalnum()
# 4.upper()
# 5.lower()

# %%
s1="abc"
s2="abc123"
s3="1234"
print(s1.isalpha()) 
print(s2.isalpha())
print(s3.isalpha())
print(s1.isdigit())
print(s2.isdigit())
print(s3.isdigit())
print(s1.isalnum()) #alphanumeric
print(s2.isalnum())
print(s3.isalnum())
# Out:
# True
# False
# False
# False
# False
# True
# True
# True
# True

# %%
s4="abc123 abc123" #space
print(s4.isalnum())
# Out:
# False

# %%
#multi line strings
s4='''abc123
abc123'''
print(s4)
# Out:
# abc123
# abc123

# %%
print(s1)
print(s1.upper())
print(s1) #strings are immutable
print(s1.lower())
# Out:
# abc
# ABC
# abc
# abc

# %%
print(s1)
s1=s1.upper()
print(s1)
# Out:
# abc
# ABC

# %%
s5="abc def Ghi"
print(s5.capitalize())
s5=s5.replace("def","xyz")
print(s5)
# Out:
# Abc def ghi
# abc xyz Ghi

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> str
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
#operators:
#arithmetic operators: +,-,*,/,%,//(floor division),**(exponent)
x=5
y=2
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x%y)
print(x//y)
print(x**y)
# Out:
# 7
# 3
# 10
# 2.5
# 1
# 2
# 25

# %%
#relational operators:<,<=,>,>=,==,!=
print(x < y)
print(x <= y)
print(x > y)
print(x >= y)
print(x == y)
print(x != y)
# Out:
# False
# False
# True
# True
# False
# True

# %%
#logical operators:and,or,not
print(x<y and x<10)
print(x<y or x<10)
print(not x)
# Out:
# False
# True
# False

# %%
#bitwise operators:&,|,^,~,<<,>>
#assignment operators:=,+=,-=,*=,/=,//=,**=
#membership: in,not in
#identity operators:is,is not

# %%
str1="abc def"
print('d' in str1)
print('d' not in str1)
# Out:
# True
# False

# %%
#identity operators
x=10
y=20
print(id(x),id(y)) #addresses
print(x is y)
# Out:
# 10914784 10915104
# False

# %%
x=10
y=10
print(id(x),id(y))
print(x is y)
# Out:
# 10914784 10914784
# True

# %%
#bitwise operators:&,|,^,~,<<,>>
x=2
y=5
print(x & y)
print(x | y)
print(~x)
print(x^y)
print(x<<y)
print(x>>y)
# Out:
# 0
# 7
# -3
# 7
# 64
# 0

# %%
print(x,y)
x if x<y else y #effective
# Out:
# 2 5
# 2

# %%
if x<y:
  print(x)
else:
  print(y)
# Out:
# 2

# %%
#control statements:
#1.if 2.else 3.elif

# %%
x=10
y=10
if x<y:
  print("x<y")
elif x>y:
  print("y<x")
else:
  print("x=y")
# Out:
# x=y

# %%
a=int(input("enter a value"))
b=int(input("enter b value"))
c=int(input("enter c value"))
if(a>b and a>c):
  print("greater number is,a")
elif b>c:
  print("b is greater")
else:
  print("c is greater")
# Out:
# enter a value20
# enter b value50
# enter c value30
# b is greater

# %%
str1=input()
x,y,z=str1.split() #input.split()
print(x)
print(y)
print(z)
# Out:
# 1 2 3
# 1
# 2
# 3

# %%
#map(function,iterable object)
a,b,c =map(int,input().split())
print(a,b,c)
# Out:
# 1 2 3
# 1 2 3

# %%
a,b,c=map(int,input().split())
if a>30 and b>30 and c>30:
  avg=(a+b+c)/3
  if avg>75:
    print("A")
  elif avg>60 and avg<75:
     print("B")
  elif avg>45 and avg<60:
     print("c")
  elif avg>30 and avg<45:
    print("D")
  else:
    print("fail")
else:
  print("fail")

# %%
#loops:
#while and for
#print 1-n values
n=int(input("enter a value"))
i=1
while i<=n:
  print(i,end"  ")
  i += 1

# %%
n=int(input("enter a number"))
c=0
print(len(str(n)))
while n!=0:
   c+=1
   n=n//10
print(c)
